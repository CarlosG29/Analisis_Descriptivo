# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar los datos desde archivo CSV
df = pd.read_csv("train.csv")

# Mostrar las primeras 5 filas del dataset
print(df.head())

# Descripcion general del dataset
print(df.info())  # Información sobre las columnas y tipos de datos
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
# Estadssticas descriptivas de las variables numericas
print(df.describe())

# Tabla de frecuencias para la columna Product Name
product_freq = df['Product Name'].value_counts()
print(product_freq.head())
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000
# Product Name
# Staple envelope            47
# Staples                    46
# Easy-staple paper          44
# Avery Non-Stick Binders    20
# Staples in misc. colors    18
# Name: count, dtype: int64

# %%
# Seleccionar las 5 ciudades con mayores ventas totales
top_10_cities = df.groupby('City')['Sales'].sum().nlargest(10)
print(top_10_cities)

# Seleccionar las 5 personas con mayores ventas totales
top_10_customers = df.groupby('Customer Name')['Sales'].sum().nlargest(5)
print(top_10_customers)
# Out:
# City
# New York City    252462.5470
# Los Angeles      173420.1810
# Seattle          116106.3220
# San Francisco    109041.1200
# Philadelphia     108841.7490
# Houston           63956.1428
# Chicago           47820.1330
# San Diego         47521.0290
# Jacksonville      44713.1830
# Detroit           42446.9440
# Name: Sales, dtype: float64
# Customer Name
# Sean Miller      25043.050
# Tamara Chand     19052.218
# Raymond Buch     15117.339
# Tom Ashbrook     14595.620
# Adrian Barton    14473.571
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt
# grafico de barras para las 5 ciudades con mayores ventas totales
top_10_cities.plot(kind='bar', title='Top 10 Ciudades con Mayores Ventas')
plt.ylabel('Ventas Totales')
plt.xlabel('Ciudad')
plt.xticks(rotation=60)
plt.show()

# %%
import matplotlib.pyplot as plt

# El histograma muestra la distribución de las ventas (`Sales`) en todo el dataset, lo que nos ayuda a entender cómo están distribuidos los datos.

plt.hist(df['Sales'], bins=20, color='yellow', edgecolor='black', linewidth=1.2)

# Ajustar el rango del eje X para mostrar numeros mas pequeños
plt.xlim(0, 4000)  
plt.ylim(0, 10000)

# Configurar el título y etiquetas del grafico
plt.title('Distribución de las Ventas')
plt.xlabel('Ventas')
plt.ylabel('Frecuencia')

plt.show()

# %%
import matplotlib.pyplot as plt
# Analizamos la relacion entre las ventas y las diferentes regiones para ver cuales están generando más ingresos.

# Crear un diagrama de dispersión para analizar la relacion entre region y ventas
plt.scatter(df['Region'], df['Sales'], alpha=0.5, color='red' )
plt.title('Relación entre Región y Ventas')
plt.xlabel('Región (Codificada)')
plt.ylabel('Ventas') 
plt.show()
